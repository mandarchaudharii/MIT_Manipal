# %% [markdown]
# # Mandar Sanjay Chaudhari
# # 220968222
# # Section B Batch B4
# # Week 8

# %% [markdown]
# # Dataset : Pulsar Dataset

# %% [markdown]
# # 1. Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Import dataset

# %%
df=pd.read_csv("pulsar_data.csv")
df
# Out:
#         Mean of the integrated profile  \
# 0                           121.156250
# 1                            76.968750
# 2                           130.585938
# 3                           156.398438
# 4                            84.804688
# ...                                ...
# 12523                       124.312500
# 12524                       115.617188
# 12525                       116.031250
# 12526                       135.664062
# 12527                       120.726562
#
#         Standard deviation of the integrated profile  \
# 0                                          48.372971
# 1                                          36.175557
# 2                                          53.229534
# 3                                          48.865942
# 4                                          36.117659
# ...                                              ...
# 12523                                      53.179053
# 12524                                      46.784600
# ...

# %% [markdown]
# # 3. Explore the data to gain insights about the data

# %%
df.shape
# Out:
# (12528, 9)

# %%
df.dtypes
# Out:
#  Mean of the integrated profile                  float64
#  Standard deviation of the integrated profile    float64
#  Excess kurtosis of the integrated profile       float64
#  Skewness of the integrated profile              float64
#  Mean of the DM-SNR curve                        float64
#  Standard deviation of the DM-SNR curve          float64
#  Excess kurtosis of the DM-SNR curve             float64
#  Skewness of the DM-SNR curve                    float64
# target_class                                     float64
# dtype: object

# %%
df.columns
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Mean of the integrated profile',
#        'Standard deviation of the integrated profile',
#        'Excess kurtosis of the integrated profile',
#        'Skewness of the integrated profile', 'Mean of the DM-SNR curve',
#        'Standard deviation of the DM-SNR curve',
#        'Excess kurtosis of the DM-SNR curve', 'Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
df.columns = ['mean_profile', 'std_profile', 'kurtosis_profile', 'skewness_profile', 'mean_dmsnr','std_dmsnr', 'kurtosis_dmsnr', 'skewness_dmsnr', 'target']
df.columns
# Out:
# Index(['mean_profile', 'std_profile', 'kurtosis_profile', 'skewness_profile',
#        'mean_dmsnr', 'std_dmsnr', 'kurtosis_dmsnr', 'skewness_dmsnr',
#        'target'],
#       dtype='object')

# %%
target_class_distribution = df['target'].value_counts()
print("Distribution of target_class:")
print(target_class_distribution)
# Out:
# Distribution of target_class:
# target
# 0.0    11375
# 1.0     1153
# Name: count, dtype: int64

# %%
df['target'].hist()
plt.show()

# %%
target_class_distribution = df['target'].value_counts(normalize=True)
print("Percentage distribution of target_class:")
print(target_class_distribution)
# Out:
# Percentage distribution of target_class:
# target
# 0.0    0.907966
# 1.0    0.092034
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#        mean_profile   std_profile  kurtosis_profile  skewness_profile  \
# count  12528.000000  12528.000000      10793.000000      12528.000000
# mean     111.041841     46.521437          0.478548          1.778431
# std       25.672828      6.801077          1.064708          6.208450
# min        5.812500     24.772042         -1.738021         -1.791886
# 25%      100.871094     42.362222          0.024652         -0.188142
# 50%      115.183594     46.931022          0.223678          0.203317
# 75%      127.109375     50.979103          0.473125          0.932374
# max      189.734375     91.808628          8.069522         68.101622
#
#          mean_dmsnr     std_dmsnr  kurtosis_dmsnr  skewness_dmsnr  \
# count  12528.000000  11350.000000    12528.000000    11903.000000
# mean      12.674758     26.351318        8.333489      105.525779
# std       29.613230     19.610842        4.535783      107.399585
# min        0.213211      7.370432       -3.139270       -1.976976
# ...

# %%
df.isnull().sum()
# Out:
# mean_profile           0
# std_profile            0
# kurtosis_profile    1735
# skewness_profile       0
# mean_dmsnr             0
# std_dmsnr           1178
# kurtosis_dmsnr         0
# skewness_dmsnr       625
# target                 0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# mean_profile        0
# std_profile         0
# kurtosis_profile    0
# skewness_profile    0
# mean_dmsnr          0
# std_dmsnr           0
# kurtosis_dmsnr      0
# skewness_dmsnr      0
# target              0
# dtype: int64

# %%
plt.figure()
sns.heatmap( df.corr(),annot=True)
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(nrows=8,ncols=2,  figsize=(15, 40))
for i in range(0,len(df.columns)-1):
    sns.distplot(df[df.columns[i]], ax=axes[i][0]).set_title("Hisotogram of " + df.columns[i])
    sns.boxplot(df[df.columns[i]], ax=axes[i][1]).set_title("Boxplot of " + df.columns[i])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7328\1386387920.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]], ax=axes[i][0]).set_title("Hisotogram of " + df.columns[i])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7328\1386387920.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df.hist(figsize=(8,8))
plt.show()

# %% [markdown]
# # 5. Split data into separate training and test set

# %%
from sklearn.model_selection import train_test_split
X = df.drop('target', axis=1)
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train
# Out:
#        mean_profile  std_profile  kurtosis_profile  skewness_profile  \
# 6478     119.914062    42.580627          0.089853          0.823671
# 617      112.437500    45.766860          0.247305          0.291442
# 9452     118.664062    52.068506          0.164080         -0.490737
# 11928    133.210938    53.357382         -0.111525         -0.392229
# 7590     109.789062    43.097573          0.313165          0.536595
# ...             ...          ...               ...               ...
# 10669    122.039062    48.921877          0.085125         -0.008021
# 12459     92.078125    35.490890          0.730128          2.575286
# 6544     121.250000    51.315811         -0.183962         -0.141365
# 4382     119.929688    57.246068          0.277253         -0.399825
# 3661     123.804688    47.974612          0.018395         -0.065274
#
#        mean_dmsnr  std_dmsnr  kurtosis_dmsnr  skewness_dmsnr
# 6478     3.474916  20.998412        7.606929       65.201828
# ...

# %%
X_test
# Out:
#        mean_profile  std_profile  kurtosis_profile  skewness_profile  \
# 11372    120.750000    43.514006          0.454148          0.597079
# 3450     126.273438    51.837594          0.031220         -0.388226
# 7024      74.476562    40.710288          1.417642          4.449731
# 1366     139.500000    50.120636         -0.109619         -0.185835
# 2444     115.882812    48.980484          0.126617          0.147435
# ...             ...          ...               ...               ...
# 974      112.414062    52.934146          0.111071         -0.209740
# 7533     121.640625    49.262647         -0.035143         -0.227049
# 5252     109.914062    52.202135          0.181999         -0.185938
# 2597     110.078125    46.503630          0.140075          0.093053
# 1313     120.046875    50.486827          0.043663         -0.524892
#
#        mean_dmsnr  std_dmsnr  kurtosis_dmsnr  skewness_dmsnr
# 11372    3.692308  20.936733        6.443120       45.747614
# ...

# %%
y_train
# Out:
# 6478     0.0
# 617      0.0
# 9452     0.0
# 11928    0.0
# 7590     0.0
#         ...
# 10669    0.0
# 12459    0.0
# 6544     0.0
# 4382     0.0
# 3661     0.0
# Name: target, Length: 6491, dtype: float64

# %%
y_test
# Out:
# 11372    0.0
# 3450     0.0
# 7024     1.0
# 1366     0.0
# 2444     0.0
#         ...
# 974      0.0
# 7533     0.0
# 5252     0.0
# 2597     0.0
# 1313     0.0
# Name: target, Length: 2782, dtype: float64

# %% [markdown]
# # 6. Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler() 
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# # 7. Run SVM with default hyperparameters
#     Run SVM with rbf kernel and C=1.0 and gamma=auto
#     Run SVM with rbf kernel and C=100.0
#     Run SVM with rbf kernel and C=1000.0

# %%
from sklearn.svm import SVC
from sklearn import svm
clf1 = svm.SVC()
clf2=svm.SVC(kernel='rbf',C=1,gamma='auto')
clf3=svm.SVC(kernel='rbf',C=100)
clf4=svm.SVC(kernel='rbf',C=1000)

# %% [markdown]
# # 8. Run SVM with linear kernel
#     Run SVM with linear kernel and C=1.0
#     Run SVM with linear kernel and C=100.0
#     Run SVM with linear kernel and C=1000.0

# %%
clf5=svm.SVC(kernel='linear')
clf6=svm.SVC(kernel='linear',C=1)
clf7=svm.SVC(kernel='linear',C=100)
clf8=svm.SVC(kernel='linear',C=1000)

# %% [markdown]
# # 9. Run SVM with polynomial kernel
#     Run SVM with polynomial kernel and C=1.0
#     Run SVM with polynomial kernel and C=100.0
#     Run SVM with polynomial kernel and C=1000.0

# %%
clf9=svm.SVC(kernel='poly')
clf10=svm.SVC(kernel='poly',C=1)
clf11=svm.SVC(kernel='poly',C=100)
clf12=svm.SVC(kernel='poly',C=1000)

# %% [markdown]
# # 10. Run SVM with sigmoid kernel
#     Run SVM with sigmoid kernel and C=1.0
#     Run SVM with sigmoid kernel and C=100.0
#     Run SVM with sigmoid kernel and C=1000.0

# %%
clf13 = svm.SVC(kernel='sigmoid')
clf14=svm.SVC(kernel='sigmoid',C=1)
clf15=svm.SVC(kernel='sigmoid',C=100)
clf16=svm.SVC(kernel='sigmoid',C=1000)

# %% [markdown]
# # 11.Compare the train-set and test-set accuracy
#
# # 12.Check for overfitting and underfitting

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, accuracy_score
classifiers = [svm.SVC(),svm.SVC(kernel='rbf',C=1,gamma='auto'),svm.SVC(kernel='rbf',C=100),svm.SVC(kernel='rbf',C=1000),svm.SVC(kernel='linear'),svm.SVC(kernel='linear',C=1),svm.SVC(kernel='linear',C=100),svm.SVC(kernel='linear',C=1000),svm.SVC(kernel='poly'),svm.SVC(kernel='poly',C=1),svm.SVC(kernel='poly',C=100),svm.SVC(kernel='poly',C=1000),svm.SVC(kernel='sigmoid'),svm.SVC(kernel='sigmoid',C=1),svm.SVC(kernel='sigmoid',C=100),svm.SVC(kernel='sigmoid',C=1000)]
evaluation_results = []
j=1
for i, clf in enumerate(classifiers):
    clf.fit(X_train, y_train)
    y_pred=clf.predict(X_test)
    y_score=clf.decision_function(X_test)
    cm=confusion_matrix(y_test, y_pred)
    cr=classification_report(y_test, y_pred)
    accuracy=accuracy_score(y_test, y_pred)
    error=1-accuracy
    roc_auc=roc_auc_score(y_test, y_score)
    fpr,tpr,_=roc_curve(y_test, y_score)
    evaluation_results.append({"model": f"Model {i+1}","confusion_matrix": cm,"classification_report": cr,"train_accuracy": clf.score(X_train, y_train),"test_accuracy": clf.score(X_test, y_test),"classification_accuracy": accuracy,"classification_error": error,"roc_auc": roc_auc,"roc_curve": (fpr, tpr)})
    print("Model",j,"completed")
    j+=1
# Out:
# Model 1 completed
# Model 2 completed
# Model 3 completed
# Model 4 completed
# Model 5 completed
# Model 6 completed
# Model 7 completed
# Model 8 completed
# Model 9 completed
# Model 10 completed
# Model 11 completed
# Model 12 completed
# Model 13 completed
# Model 14 completed
# Model 15 completed
# Model 16 completed

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    print(f"Train Accuracy: {result['train_accuracy']:.2f}")
    print(f"Test Accuracy : {result['test_accuracy']:.2f}")
    i+=1
# Out:
# Model 1
# Train Accuracy: 0.98
# Test Accuracy : 0.98
# Model 2
# Train Accuracy: 0.98
# Test Accuracy : 0.98
# Model 3
# Train Accuracy: 0.98
# Test Accuracy : 0.98
# Model 4
# Train Accuracy: 0.99
# Test Accuracy : 0.98
# Model 5
# Train Accuracy: 0.98
# Test Accuracy : 0.98
# Model 6
# Train Accuracy: 0.98
# Test Accuracy : 0.98
# Model 7
# Train Accuracy: 0.98
# Test Accuracy : 0.98
# Model 8
# Train Accuracy: 0.98
# Test Accuracy : 0.98
# Model 9
# Train Accuracy: 0.98
# Test Accuracy : 0.97
# Model 10
# Train Accuracy: 0.98
# Test Accuracy : 0.97
# Model 11
# Train Accuracy: 0.98
# Test Accuracy : 0.98
# Model 12
# Train Accuracy: 0.98
# Test Accuracy : 0.98
# Model 13
# Train Accuracy: 0.87
# Test Accuracy : 0.87
# Model 14
# Train Accuracy: 0.87
# Test Accuracy : 0.87
# Model 15
# Train Accuracy: 0.87
# Test Accuracy : 0.87
# Model 16
# Train Accuracy: 0.87
# Test Accuracy : 0.87

# %% [markdown]
# # 13. visualize confusion matrix with seaborn heatmap

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    plt.figure()
    sns.heatmap(result['confusion_matrix'],annot=True)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.show()
    i+=1
# Out:
# Model 1
# Model 2
# Model 3
# Model 4
# Model 5
# Model 6
# Model 7
# Model 8
# Model 9
# Model 10
# Model 11
# Model 12
# Model 13
# Model 14
# Model 15
# Model 16

# %% [markdown]
# # 14. Generate classification report

# %%
i=1
for result in evaluation_results:
    print("Model",i,"Classification Report")
    print(result['classification_report'])
    i+=1
# Out:
# Model 1 Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      2525
#          1.0       0.93      0.80      0.86       257
#
#     accuracy                           0.98      2782
#    macro avg       0.95      0.90      0.92      2782
# weighted avg       0.97      0.98      0.97      2782
#
# Model 2 Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      2525
#          1.0       0.93      0.80      0.86       257
#
#     accuracy                           0.98      2782
#    macro avg       0.95      0.90      0.92      2782
# weighted avg       0.97      0.98      0.97      2782
#
# Model 3 Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      2525
#          1.0       0.93      0.82      0.87       257
#
# ...

# %% [markdown]
# # 15. Evaluate classification accuracy
#
# # 16. Evaluate Classification error

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    print(f"Classification Accuracy: {result['classification_accuracy']:.2f}")
    print(f"Classification Error: {result['classification_error']:.2f}")
    i+=1
# Out:
# Model 1
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 2
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 3
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 4
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 5
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 6
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 7
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 8
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 9
# Classification Accuracy: 0.97
# Classification Error: 0.03
# Model 10
# Classification Accuracy: 0.97
# Classification Error: 0.03
# Model 11
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 12
# Classification Accuracy: 0.98
# Classification Error: 0.02
# Model 13
# Classification Accuracy: 0.87
# Classification Error: 0.13
# Model 14
# Classification Accuracy: 0.87
# Classification Error: 0.13
# ...

# %% [markdown]
# # 17. Plot ROC Curve

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    plt.figure()
    plt.plot(result['roc_curve'][0], result['roc_curve'][1])
    plt.plot()
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.show()
    i+=1
# Out:
# Model 1
# Model 2
# Model 3
# Model 4
# Model 5
# Model 6
# Model 7
# Model 8
# Model 9
# Model 10
# Model 11
# Model 12
# Model 13
# Model 14
# Model 15
# Model 16

# %% [markdown]
# # 18. Compute ROC AUC

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    print(result['roc_auc'])
    i+=1
# Out:
# Model 1
# 0.9569241437762452
# Model 2
# 0.9569241437762452
# Model 3
# 0.9552151635397003
# Model 4
# 0.9474207342913279
# Model 5
# 0.9778063720768965
# Model 6
# 0.9778063720768965
# Model 7
# 0.9778294872288784
# Model 8
# 0.9779758831914319
# Model 9
# 0.9642793851369573
# Model 10
# 0.9642793851369573
# Model 11
# 0.9533875255229802
# Model 12
# 0.9541441614978619
# Model 13
# 0.8713349000269677
# Model 14
# 0.8713349000269677
# Model 15
# 0.8708525638556074
# Model 16
# 0.8708525638556074

# %% [markdown]
# # 19. Stratified k-fold cross-validation with shuffle split with linear kernel

# %%
from sklearn.model_selection import StratifiedKFold, ShuffleSplit, cross_val_score
stratified_kfold = StratifiedKFold(n_splits=3, shuffle=True)
shuffle_split = ShuffleSplit(n_splits=3, test_size=0.2, random_state=42)
cv_scores = cross_val_score(clf5, X, y, cv=stratified_kfold, n_jobs=-1)
print("Cross-validation scores: {}".format(cv_scores))
print("Mean accuracy: {:.2f}".format(np.mean(cv_scores)))
# Out:
# Cross-validation scores: [0.97735361 0.97897121 0.98026529]
# Mean accuracy: 0.98

# %% [markdown]
# # 21. Stratified k-fold cross-validation with shuffle split with rbf kernel

# %%
stratified_kfold = StratifiedKFold(n_splits=3, shuffle=True)
shuffle_split = ShuffleSplit(n_splits=3, test_size=0.2, random_state=42)
cv_scores = cross_val_score(clf2, X, y, cv=stratified_kfold, n_jobs=-1)
print("Cross-validation scores: {}".format(cv_scores))
print("Mean accuracy: {:.2f}".format(np.mean(cv_scores)))
# Out:
# Cross-validation scores: [0.90876739 0.90876739 0.90844387]
# Mean accuracy: 0.91

# %% [markdown]
# # 22. Stratified k-fold cross-validation with shuffle split with polynomial kernel

# %%
stratified_kfold = StratifiedKFold(n_splits=3, shuffle=True)
shuffle_split = ShuffleSplit(n_splits=3, test_size=0.2, random_state=42)
cv_scores = cross_val_score(clf9, X, y, cv=stratified_kfold, n_jobs=-1)
print("Cross-validation scores: {}".format(cv_scores))
print("Mean accuracy: {:.2f}".format(np.mean(cv_scores)))
# Out:
# Cross-validation scores: [0.96894209 0.97120673 0.97314785]
# Mean accuracy: 0.97

# %% [markdown]
# # 23. Stratified k-fold cross-validation with shuffle split with sigmoid kernel

# %%
stratified_kfold = StratifiedKFold(n_splits=3, shuffle=True)
shuffle_split = ShuffleSplit(n_splits=3, test_size=0.2, random_state=42)
cv_scores = cross_val_score(clf14, X, y, cv=stratified_kfold, n_jobs=-1)
print("Cross-validation scores: {}".format(cv_scores))
print("Mean accuracy: {:.2f}".format(np.mean(cv_scores)))
# Out:
# Cross-validation scores: [0.92559042 0.92817858 0.92785506]
# Mean accuracy: 0.93

# %% [markdown]
# # Income Evaluation Dataset

# %% [markdown]
# # 2. Import dataset

# %%
df=pd.read_csv("income_evaluation.csv")
df
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# # 3. Explore the data to gain insights about the data

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.dtypes
# Out:
# age                 int64
#  workclass         object
#  fnlwgt             int64
#  education         object
#  education-num      int64
#  marital-status    object
#  occupation        object
#  relationship      object
#  race              object
#  sex               object
#  capital-gain       int64
#  capital-loss       int64
#  hours-per-week     int64
#  native-country    object
#  income            object
# dtype: object

# %%
df.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' income'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
target_class_distribution = df['income'].value_counts()
print("Distribution of target_class:")
print(target_class_distribution)
# Out:
# Distribution of target_class:
# income
#  <=50K    24720
#  >50K      7841
# Name: count, dtype: int64

# %%
df['income'].hist()
plt.show()

# %%
target_class_distribution = df['income'].value_counts(normalize=True)
print("Percentage distribution of target_class:")
print(target_class_distribution)
# Out:
# Percentage distribution of target_class:
# income
#  <=50K    0.75919
#  >50K     0.24081
# Name: proportion, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
for col_name in df.columns:
    le = LabelEncoder()
    df[col_name] = le.fit_transform(df[col_name])

# %%
df.describe()
# Out:
#                 age     workclass        fnlwgt     education  education-num  \
# count  32561.000000  32561.000000  32561.000000  32561.000000   32561.000000
# mean      21.580326      3.868892  10498.892479     10.298210       9.080679
# std       13.635502      1.455960   6048.972814      3.870264       2.572720
# min        0.000000      0.000000      0.000000      0.000000       0.000000
# 25%       11.000000      4.000000   5396.000000      9.000000       8.000000
# 50%       20.000000      4.000000  10348.000000     11.000000       9.000000
# 75%       31.000000      4.000000  15487.000000     12.000000      11.000000
# max       72.000000      8.000000  21647.000000     15.000000      15.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean         2.611836      6.572740      1.446362      3.665858      0.669205
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
plt.figure(figsize=(12,12))
sns.heatmap( df.corr(),annot=True)
plt.show()

# %%
df.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# # 5. Split data into separate training and test set

# %%
from sklearn.model_selection import train_test_split
X = df.drop('income', axis=1)
y = df['income']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 32098   28          4    9520         11              8               2
# 25206   30          7    4595         11              8               0
# 23491   31          4   11343         15              9               2
# 12367   12          4    7420         11              8               4
# 7054     6          4   13029          5              3               4
# ...    ...        ...     ...        ...            ...             ...
# 13123   26          2     635         12             13               2
# 19648   27          4    3736          0              5               4
# 9845     6          4    1295         15              9               5
# 10799   28          2   14095         10             15               2
# 2732     8          4   11269         15              9               4
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
X_test
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 22278   10          4   10208         15              9               0
# 8950    10          4   14147          9             12               4
# 7838     8          4   16474          7             11               2
# 16505   29          4    7575          4              2               2
# 19140   28          4    9700          1              6               0
# ...    ...        ...     ...        ...            ...             ...
# 21949   29          4   11978          9             12               2
# 26405   47          1   20446         14             14               2
# 23236   37          5   18382          9             12               2
# 26823   19          6    3265         15              9               2
# 20721    5          4    2927         11              8               4
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
y_train
# Out:
# 32098    1
# 25206    0
# 23491    1
# 12367    0
# 7054     0
#         ..
# 13123    1
# 19648    0
# 9845     0
# 10799    1
# 2732     0
# Name: income, Length: 22792, dtype: int32

# %%
y_test
# Out:
# 22278    0
# 8950     0
# 7838     0
# 16505    0
# 19140    1
#         ..
# 21949    1
# 26405    1
# 23236    1
# 26823    0
# 20721    0
# Name: income, Length: 9769, dtype: int32

# %% [markdown]
# # 6. Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler() 
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# # 7. Run SVM with default hyperparameters
#     Run SVM with rbf kernel and C=1.0 and gamma=auto
#     Run SVM with rbf kernel and C=100.0
#     Run SVM with rbf kernel and C=1000.0

# %%
from sklearn.svm import SVC
from sklearn import svm
clf1 = svm.SVC()
clf2=svm.SVC(kernel='rbf',C=1,gamma='auto')
clf3=svm.SVC(kernel='rbf',C=20)
clf4=svm.SVC(kernel='rbf',C=50)

# %% [markdown]
# # 8. Run SVM with linear kernel
#     Run SVM with linear kernel and C=1.0
#     Run SVM with linear kernel and C=100.0
#     Run SVM with linear kernel and C=1000.0

# %%
clf5=svm.SVC(kernel='linear')
clf6=svm.SVC(kernel='linear',C=1)
clf7=svm.SVC(kernel='linear',C=20)
clf8=svm.SVC(kernel='linear',C=50)

# %% [markdown]
# # 9. Run SVM with polynomial kernel
#     Run SVM with polynomial kernel and C=1.0
#     Run SVM with polynomial kernel and C=100.0
#     Run SVM with polynomial kernel and C=1000.0

# %%
clf9=svm.SVC(kernel='poly')
clf10=svm.SVC(kernel='poly',C=1)
clf11=svm.SVC(kernel='poly',C=20)
clf12=svm.SVC(kernel='poly',C=50)

# %% [markdown]
# # 10. Run SVM with sigmoid kernel
#     Run SVM with sigmoid kernel and C=1.0
#     Run SVM with sigmoid kernel and C=100.0
#     Run SVM with sigmoid kernel and C=1000.0

# %%
clf13 = svm.SVC(kernel='sigmoid')
clf14=svm.SVC(kernel='sigmoid',C=1)
clf15=svm.SVC(kernel='sigmoid',C=20)
clf16=svm.SVC(kernel='sigmoid',C=50)

# %% [markdown]
# # 11.Compare the train-set and test-set accuracy
#
# # 12.Check for overfitting and underfitting

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, accuracy_score
classifiers = [svm.SVC(),svm.SVC(kernel='rbf',C=1,gamma='auto'),svm.SVC(kernel='rbf',C=20),svm.SVC(kernel='rbf',C=50),svm.SVC(kernel='linear'),svm.SVC(kernel='linear',C=1),svm.SVC(kernel='linear',C=20),svm.SVC(kernel='linear',C=50),svm.SVC(kernel='poly'),svm.SVC(kernel='poly',C=1),svm.SVC(kernel='poly',C=20),svm.SVC(kernel='poly',C=50),svm.SVC(kernel='sigmoid'),svm.SVC(kernel='sigmoid',C=1),svm.SVC(kernel='sigmoid',C=20),svm.SVC(kernel='sigmoid',C=50)]
evaluation_results = []
j=1
for i, clf in enumerate(classifiers):
    clf.fit(X_train, y_train)
    y_pred=clf.predict(X_test)
    y_score=clf.decision_function(X_test)
    cm=confusion_matrix(y_test, y_pred)
    cr=classification_report(y_test, y_pred)
    accuracy=accuracy_score(y_test, y_pred)
    error=1-accuracy
    roc_auc=roc_auc_score(y_test, y_score)
    fpr,tpr,_=roc_curve(y_test, y_score)
    evaluation_results.append({"model": f"Model {i+1}","confusion_matrix": cm,"classification_report": cr,"train_accuracy": clf.score(X_train, y_train),"test_accuracy": clf.score(X_test, y_test),"classification_accuracy": accuracy,"classification_error": error,"roc_auc": roc_auc,"roc_curve": (fpr, tpr)})
    print("Model",j,"completed")
    j+=1
# Out:
# Model 1 completed
# Model 2 completed
# Model 3 completed
# Model 4 completed
# Model 5 completed
# Model 6 completed
# Model 7 completed
# Model 8 completed
# Model 9 completed
# Model 10 completed
# Model 11 completed
# Model 12 completed
# Model 13 completed
# Model 14 completed
# Model 15 completed
# Model 16 completed

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    print(f"Train Accuracy: {result['train_accuracy']:.2f}")
    print(f"Test Accuracy : {result['test_accuracy']:.2f}")
    i+=1
# Out:
# Model 1
# Train Accuracy: 0.86
# Test Accuracy : 0.85
# Model 2
# Train Accuracy: 0.86
# Test Accuracy : 0.85
# Model 3
# Train Accuracy: 0.88
# Test Accuracy : 0.85
# Model 4
# Train Accuracy: 0.89
# Test Accuracy : 0.85
# Model 5
# Train Accuracy: 0.81
# Test Accuracy : 0.81
# Model 6
# Train Accuracy: 0.81
# Test Accuracy : 0.81
# Model 7
# Train Accuracy: 0.81
# Test Accuracy : 0.81
# Model 8
# Train Accuracy: 0.81
# Test Accuracy : 0.81
# Model 9
# Train Accuracy: 0.85
# Test Accuracy : 0.85
# Model 10
# Train Accuracy: 0.85
# Test Accuracy : 0.85
# Model 11
# Train Accuracy: 0.85
# Test Accuracy : 0.85
# Model 12
# Train Accuracy: 0.85
# Test Accuracy : 0.85
# Model 13
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# Model 14
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# Model 15
# Train Accuracy: 0.75
# Test Accuracy : 0.75
# Model 16
# Train Accuracy: 0.75
# Test Accuracy : 0.74

# %% [markdown]
# # 13. visualize confusion matrix with seaborn heatmap

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    plt.figure()
    sns.heatmap(result['confusion_matrix'],annot=True)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.show()
    i+=1
# Out:
# Model 1
# Model 2
# Model 3
# Model 4
# Model 5
# Model 6
# Model 7
# Model 8
# Model 9
# Model 10
# Model 11
# Model 12
# Model 13
# Model 14
# Model 15
# Model 16

# %% [markdown]
# # 14. Generate classification report

# %%
i=1
for result in evaluation_results:
    print("Model",i,"Classification Report")
    print(result['classification_report'])
    i+=1
# Out:
# Model 1 Classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90      7407
#            1       0.75      0.55      0.64      2362
#
#     accuracy                           0.85      9769
#    macro avg       0.81      0.75      0.77      9769
# weighted avg       0.84      0.85      0.84      9769
#
# Model 2 Classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90      7407
#            1       0.75      0.55      0.64      2362
#
#     accuracy                           0.85      9769
#    macro avg       0.81      0.75      0.77      9769
# weighted avg       0.84      0.85      0.84      9769
#
# Model 3 Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      7407
#            1       0.73      0.59      0.65      2362
#
# ...

# %% [markdown]
# # 15. Evaluate classification accuracy
#
# # 16. Evaluate Classification error

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    print(f"Classification Accuracy: {result['classification_accuracy']:.2f}")
    print(f"Classification Error: {result['classification_error']:.2f}")
    i+=1
# Out:
# Model 1
# Classification Accuracy: 0.85
# Classification Error: 0.15
# Model 2
# Classification Accuracy: 0.85
# Classification Error: 0.15
# Model 3
# Classification Accuracy: 0.85
# Classification Error: 0.15
# Model 4
# Classification Accuracy: 0.85
# Classification Error: 0.15
# Model 5
# Classification Accuracy: 0.81
# Classification Error: 0.19
# Model 6
# Classification Accuracy: 0.81
# Classification Error: 0.19
# Model 7
# Classification Accuracy: 0.81
# Classification Error: 0.19
# Model 8
# Classification Accuracy: 0.81
# Classification Error: 0.19
# Model 9
# Classification Accuracy: 0.85
# Classification Error: 0.15
# Model 10
# Classification Accuracy: 0.85
# Classification Error: 0.15
# Model 11
# Classification Accuracy: 0.85
# Classification Error: 0.15
# Model 12
# Classification Accuracy: 0.85
# Classification Error: 0.15
# Model 13
# Classification Accuracy: 0.75
# Classification Error: 0.25
# Model 14
# Classification Accuracy: 0.75
# Classification Error: 0.25
# ...

# %% [markdown]
# # 17. Plot ROC Curve

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    plt.figure()
    plt.plot(result['roc_curve'][0], result['roc_curve'][1])
    plt.plot()
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.show()
    i+=1
# Out:
# Model 1
# Model 2
# Model 3
# Model 4
# Model 5
# Model 6
# Model 7
# Model 8
# Model 9
# Model 10
# Model 11
# Model 12
# Model 13
# Model 14
# Model 15
# Model 16

# %% [markdown]
# # 18. Compute ROC AUC

# %%
i=1
for result in evaluation_results:
    print("Model",i)
    print(result['roc_auc'])
    i+=1
# Out:
# Model 1
# 0.8915449685041738
# Model 2
# 0.8915449685041738
# Model 3
# 0.8822248263451273
# Model 4
# 0.8774353779127624
# Model 5
# 0.8483741436430993
# Model 6
# 0.8483741436430993
# Model 7
# 0.8483559102101166
# Model 8
# 0.8483536238862316
# Model 9
# 0.8763416005661852
# Model 10
# 0.8763416005661852
# Model 11
# 0.8786567321321215
# Model 12
# 0.877557181817735
# Model 13
# 0.7247571838296999
# Model 14
# 0.7247571838296999
# Model 15
# 0.7221650641250976
# Model 16
# 0.7204370605328254
